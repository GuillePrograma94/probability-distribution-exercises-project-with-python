# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %% [markdown]
# NORMAL DISTRIBUTION

# %%
# We import for Normal Distribution from stats.
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np

# Function definitions
def dnorm(x, mean=0, std=1):
    #Density function of the normal distribution.
    return norm.pdf(x, loc=mean, scale=std)

def pnorm(x, mean=0, std=1):
    #Cumulative function of the normal distribution.
    return norm.cdf(x, loc=mean, scale=std)

def qnorm(p, mean=0, std=1):
    #Quantile function of the normal distribution.
    return norm.ppf(q=p, loc=mean, scale=std)

def rnorm(n, mean=0, std=1):
    #Random variates from the normal distribution.
    return norm.rvs(size=n, loc=mean, scale=std)

# Data generation
x_values = np.linspace(-4, 4, 800)

# Calculations
density = dnorm(x_values)
cumulative = pnorm(x_values)
quantile = qnorm(x_values)

# Plotting
fig, axes = plt.subplots(2, 2, figsize=(10, 10), sharex=True)

# Density plot
axes[0, 0].fill_between(x_values, density, color="skyblue", alpha=0.5)
axes[0, 0].plot(x_values, density, color="Slateblue", alpha=0.6, linewidth=2)
axes[0, 0].set_title('Normal Distribution - PDF', fontsize=14)
axes[0, 0].set_ylabel('Density')
axes[0, 0].grid(True)

# Cumulative plot
axes[0, 1].step(x_values, cumulative, color="darkorange", alpha=0.6, where='mid')
axes[0, 1].set_title('Normal Distribution - CDF', fontsize=14)
axes[0, 1].set_ylabel('Cumulative Probability')
axes[0, 1].grid(True)

# Quantile plot
axes[1, 0].scatter(x_values, quantile, color="green", alpha=0.6, edgecolors='w', s=10)
axes[1, 0].set_title('Normal Distribution - PPF', fontsize=14)
axes[1, 0].set_xlabel('Probability')
axes[1, 0].set_ylabel('Quantile')
axes[1, 0].grid(True)

# Hide the unused subplot
axes[1, 1].axis('off')

# Adjust layout and show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# UNIFORM DISTRIBUTION

# %%
from scipy.stats import uniform

# Function definitions
def duniform(x, loc=0, scale=1):
    """Density function of the uniform distribution."""
    return uniform.pdf(x, loc=loc, scale=scale)

def puniform(x, loc=0, scale=1):
    """Cumulative function of the uniform distribution."""
    return uniform.cdf(x, loc=loc, scale=scale)

def quniform(p, loc=0, scale=1):
    """Quantile function of the uniform distribution."""
    return uniform.ppf(p, loc=loc, scale=scale)

def runiform(n, loc=0, scale=1):
    """Random variates from the uniform distribution."""
    return uniform.rvs(size=n, loc=loc, scale=scale)

# Data generation
x_values = np.linspace(-1, 2, 800)  # Covering a broader range to capture the uniform distribution

# Calculations
density = duniform(x_values)
cumulative = puniform(x_values)
quantile = quniform(x_values)  # Using x_values directly for quantile function

# Plotting
fig, axes = plt.subplots(2, 2, figsize=(10, 10), sharex=True)

# Density plot
axes[0, 0].fill_between(x_values, density, color="skyblue", alpha=0.5)
axes[0, 0].plot(x_values, density, color="Slateblue", alpha=0.6, linewidth=2)
axes[0, 0].set_title('Uniform Distribution - PDF', fontsize=14)
axes[0, 0].set_ylabel('Density')
axes[0, 0].grid(True)

# Cumulative plot
axes[0, 1].step(x_values, cumulative, color="darkorange", alpha=0.6, where='mid')
axes[0, 1].set_title('Uniform Distribution - CDF', fontsize=14)
axes[0, 1].set_ylabel('Cumulative Probability')
axes[0, 1].grid(True)

# Quantile plot
axes[1, 0].plot(x_values, quantile, color="green", alpha=0.6, linewidth=2)
axes[1, 0].set_title('Uniform Distribution - PPF', fontsize=14)
axes[1, 0].set_xlabel('Probability')
axes[1, 0].set_ylabel('Quantile')
axes[1, 0].grid(True)

# Hide the unused subplot
axes[1, 1].axis('off')

# Adjust layout and show plot
plt.tight_layout()
plt.show()
